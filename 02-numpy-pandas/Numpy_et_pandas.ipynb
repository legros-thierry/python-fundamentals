# %% [markdown]
# <a href="https://colab.research.google.com/github/THLDevAndTech/python-fundamentals/blob/main/Numpy_et_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

a = np.array([1,15,9,12])
moy = np.mean(a)
print(moy)
# Out:
# 9.25

# %%
4 + 5
# Out:
# 9

# %%
print ("Hello world")
# Out:
# Hello world

# %%
import numpy as np
import pandas as pd

personnes = np.array(["Bernard", "Maurice", "Brigitte", "Pamela"])
notes = np.array([
    [13,16,17.5,18,16.5],
    [11,14,12,15,12.5],
    [13,8,19,15,12],
    [9,11,14,11,13]
])

notes.mean(axis=1)
# Out:
# array([16.2, 12.9, 13.4, 11.6])

# %%
import numpy as np
import pandas as pd

personnes = np.array(["Bernard", "Maurice", "Brigitte", "Pamela"])
notes = np.array([
    [13,16,17.5,18,16.5],
    [11,14,12,15,12.5],
    [13,8,19,15,12],
    [9,11,14,11,13]
])

df = pd.DataFrame(
    notes,
    index=personnes,
    columns=["note1", "note2", "note3", "note4", "note5"]
)

df
# Out:
#           note1  note2  note3  note4  note5
# Bernard    13.0   16.0   17.5   18.0   16.5
# Maurice    11.0   14.0   12.0   15.0   12.5
# Brigitte   13.0    8.0   19.0   15.0   12.0
# Pamela      9.0   11.0   14.0   11.0   13.0

# %%
import matplotlib.pyplot as plt

# Assuming df_row_means has been calculated and contains the average note for each person
# If df_row_means is not yet in the notebook, I'll calculate it first.
# Based on the kernel state, df_row_means is available.

plt.figure(figsize=(10, 6))
plt.bar(df_row_means.index, df_row_means.values, color='skyblue')
plt.xlabel('Personnes')
plt.ylabel('Moyenne des Notes')
plt.title('Moyenne des Notes par Personne')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       3 # Assuming df_row_means has been calculated and contains the average note for each person
#       4 # If df_row_means is not yet in the notebook, I'll calculate it first.
#       5 # Based on the kernel state, df_row_means is available.
#       7 plt.figure(figsize=(10, 6))
# ----> 8 plt.bar(df_row_means.index, df_row_means.values, color='skyblue')
#       9 plt.xlabel('Personnes')
#      10 plt.ylabel('Moyenne des Notes')
#
# NameError: name 'df_row_means' is not defined

# %%
df["moyenne"] = df.mean(axis=1)
df
# Out:
#           note1  note2  note3  note4  note5  moyenne
# Bernard    13.0   16.0   17.5   18.0   16.5     16.2
# Maurice    11.0   14.0   12.0   15.0   12.5     12.9
# Brigitte   13.0    8.0   19.0   15.0   12.0     13.4
# Pamela      9.0   11.0   14.0   11.0   13.0     11.6

# %%
df.loc['Ecart-type'] = df.std()
display(df)
# Out:
#                 note1  note2      note3      note4      note5    moyenne
# Bernard     13.000000   16.0  17.500000  18.000000  16.500000  16.200000
# Maurice     11.000000   14.0  12.000000  15.000000  12.500000  12.900000
# Brigitte    13.000000    8.0  19.000000  15.000000  12.000000  13.400000
# Pamela       9.000000   11.0  14.000000  11.000000  13.000000  11.600000
# Ecart-type   1.914854    3.5   3.198307   2.872281   2.041241   1.937997

# %%
df.loc['Moyenne des moyennes'] = df.loc[:'Pamela', 'moyenne'].mean()
display(df)
# Out:
#                           note1   note2      note3      note4      note5  \
# Bernard               13.000000  16.000  17.500000  18.000000  16.500000
# Maurice               11.000000  14.000  12.000000  15.000000  12.500000
# Brigitte              13.000000   8.000  19.000000  15.000000  12.000000
# Pamela                 9.000000  11.000  14.000000  11.000000  13.000000
# Ecart-type             1.914854   3.500   3.198307   2.872281   2.041241
# Moyenne des moyennes  13.525000  13.525  13.525000  13.525000  13.525000
#
#                         moyenne
# Bernard               16.200000
# Maurice               12.900000
# Brigitte              13.400000
# Pamela                11.600000
# Ecart-type             1.937997
# Moyenne des moyennes  13.525000

# %%
html_table = df.to_html()
print(html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>note1</th>
#       <th>note2</th>
#       <th>note3</th>
#       <th>note4</th>
#       <th>note5</th>
#       <th>moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Bernard</th>
#       <td>13.000000</td>
#       <td>16.000</td>
#       <td>17.500000</td>
#       <td>18.000000</td>
#       <td>16.500000</td>
#       <td>16.200000</td>
#     </tr>
#     <tr>
#       <th>Maurice</th>
#       <td>11.000000</td>
#       <td>14.000</td>
#       <td>12.000000</td>
#       <td>15.000000</td>
#       <td>12.500000</td>
#       <td>12.900000</td>
#     </tr>
#     <tr>
#       <th>Brigitte</th>
#       <td>13.000000</td>
#       <td>8.000</td>
#       <td>19.000000</td>
#       <td>15.000000</td>
#       <td>12.000000</td>
#       <td>13.400000</td>
#     </tr>
#     <tr>
#       <th>Pamela</th>
#       <td>9.000000</td>
#       <td>11.000</td>
# ...
